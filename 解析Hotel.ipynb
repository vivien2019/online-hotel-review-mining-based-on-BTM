# %%
import pandas as pd

# %%
df=pd.read_csv(r'E:\Django\recommend\BTM-master\BTM\sample-data\Hotel_Reviews.csv')
df.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
df['Negative_Review']
# Out:
# 0          I am so angry that i made this post available...
# 1                                               No Negative
# 2          Rooms are nice but for elderly a bit difficul...
# 3          My room was dirty and I was afraid to walk ba...
# 4          You When I booked with your company on line y...
#                                 ...
# 515733     no trolly or staff to help you take the lugga...
# 515734             The hotel looks like 3 but surely not 4
# 515735     The ac was useless It was a hot week in vienn...
# 515736                                          No Negative
# 515737         I was in 3rd floor It didn t work Free Wife
# Name: Negative_Review, Length: 515738, dtype: object

# %%
with open('stopwords.txt','r')as f:
    stopwords=[row.strip() for row in f.readlines()]

# %%
len(x),x[:6]
# Out:
# (726730,
#  [' I angry post sites planing trips mistake booking I booking booking We stayed 6 nights hotel 11 17 July Upon arrival 2nd floor hotel It booked I specially reserved 2 level duplex windows ceilings The don mind broken window closed rain mini fridge contained sort bio weapon guessed smell I intimately change explaining 2 times booked duplex btw costs simple double volume ceiling offered day SO check day 11 clock waned Not holiday So wait till 13 00 check wonderful waist time The 023 peaceful internal garden view window We tired waiting belongings rushed city In evening constant noise guess vibrating vent tubes constant annoying hell AND 2 hard fall asleep wife I audio recording attach send mail The day technician determine disturbing sound offered change hotel booked 1 left ',
#   ' Rooms nice elderly bit difficult story narrow steps So single level Inside basic tea coffee boiler bar empty fridge ',
# ...

# %%
x=[]
for row in df.drop_duplicates(subset=['Negative_Review'],keep=False)['Negative_Review']:
    words=[]
    for word in row.split(' '):
        if word not in stopwords:
            words.append(word)
    x.append(' '.join(words))

# %%
for row in df.drop_duplicates(subset=['Positive_Review'],keep=False)['Positive_Review']:
    words=[]
    for word in row.split(' '):
        if word not in stopwords:
            words.append(word)
    x.append(' '.join(words))

# %%
with open('hotel_review.txt','w')as f:
    for row in data.drop_duplicates(subset=['review'],keep=False)['review']:
        if row !=' ' or row !='' or row!='\n':
            f.write(row.strip()+'\n')

# %%
x[0]
# Out:
# '  I                                                               I               W       6             1 1     1 7   J   U                       2           I                       I           2                               T                                                                                     I                     2                                                                       S O                     1 1                         N                 S             1 3   0 0                                 T     0 2 3                               W                                   I                                                                   A N D               2                           I                                             T                                                                           1                      '

# %%
stopwords
# Out:
# ["'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'t",
#  "'ve",
#  'ZT',
#  'ZZ',
#  'a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'abst',
#  'accordance',
#  'according',
#  'accordingly',
#  'across',
#  'act',
#  'actually',
#  'added',
#  'adj',
#  'adopted',
#  'affected',
#  'affecting',
#  'affects',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ah',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'announce',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'apparently',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'approximately',
#  'are',
#  'area',
#  'areas',
#  'aren',
#  "aren't",
#  'arent',
#  'arise',
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'associated',
# ...

# %%
x[0].lower()
# Out:
# ' i angry post sites planing trips mistake booking i booking booking we stayed 6 nights hotel 11 17 july upon arrival 2nd floor hotel it booked i specially reserved 2 level duplex windows ceilings the don mind broken window closed rain mini fridge contained sort bio weapon guessed smell i intimately change explaining 2 times booked duplex btw costs simple double volume ceiling offered day so check day 11 clock waned not holiday so wait till 13 00 check wonderful waist time the 023 peaceful internal garden view window we tired waiting belongings rushed city in evening constant noise guess vibrating vent tubes constant annoying hell and 2 hard fall asleep wife i audio recording attach send mail the day technician determine disturbing sound offered change hotel booked 1 left '

# %%
X=pd.Series(x)
X
# Out:
# 0          I angry post sites planing trips mistake book...
# 1          Rooms nice elderly bit difficult story narrow...
# 2          My dirty I afraid walk barefoot floor looked ...
# 3          You When I booked company pictures I I paying...
# 4          Backyard hotel total mess shouldn happen hote...
#                                 ...
# 726725     The breakfast excelent lots fress fruits The ...
# 726726      helpful staff allowed check arrived check time
# 726727                             Breakfast earlier check
# 726728     The enormous comfortable I family 5 comfy spa...
# 726729                                               staff
# Length: 726730, dtype: object

# %%
def f(x):
    words=[]
    for word in x.strip().lower().split(' '):
        if word not in stopwords:
            words.append(word)
    return ' '.join(words)
Y=X.map(f)
Y[:8]
# Out:
# 0    angry post sites planing trips mistake booking...
# 1    nice elderly bit difficult story narrow steps ...
# 2    dirty afraid walk barefoot floor looked cleane...
# 3    booked company pictures paying arrived booked ...
# 4    backyard hotel total mess shouldn happen hotel...
# 5    cleaner change sheet duvet everyday bed didn c...
# 6                                       price brekfast
# 7    pictures clean actual quit dirty outlived chec...
# dtype: object

# %%
Y.value_counts()
# Out:
#                                                                                       3733
# location                                                                              1240
# breakfast                                                                              690
# hotel                                                                                  611
# staff                                                                                  444
#                                                                                       ...
# excellent location beach restaurantsee walking distance                                  1
# didn love quiet bit makeover maintenance match rest                                      1
# terribly money secon amazing                                                             1
# location hotel excellent renovations progress impact stay pleasant staff reception       1
# ...

# %%
data=pd.DataFrame(Y,columns=['review'])
data
# Out:
#                                                    review
# 0       angry post sites planing trips mistake booking...
# 1       nice elderly bit difficult story narrow steps ...
# 2       dirty afraid walk barefoot floor looked cleane...
# 3       booked company pictures paying arrived booked ...
# 4       backyard hotel total mess shouldn happen hotel...
# ...                                                   ...
# 726725  breakfast excelent lots fress fruits hotel ace...
# 726726     helpful staff allowed check arrived check time
# 726727                            breakfast earlier check
# 726728         enormous comfortable family 5 comfy spaces
# 726729                                              staff
#
# [726730 rows x 1 columns]

# %%
data.drop_duplicates(subset=['review'],keep=False)
# Out:
#                                                    review
# 0       angry post sites planing trips mistake booking...
# 1       nice elderly bit difficult story narrow steps ...
# 2       dirty afraid walk barefoot floor looked cleane...
# 3       booked company pictures paying arrived booked ...
# 4       backyard hotel total mess shouldn happen hotel...
# ...                                                   ...
# 726724                           cheap center tram subway
# 726725  breakfast excelent lots fress fruits hotel ace...
# 726726     helpful staff allowed check arrived check time
# 726727                            breakfast earlier check
# 726728         enormous comfortable family 5 comfy spaces
#
# [622565 rows x 1 columns]

# %%
x=[1,2,3]
y=[2,4]
x+y
# Out:
# [1, 2, 3, 2, 4]
